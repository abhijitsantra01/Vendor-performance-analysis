# %%
import pandas as pd
data = pd.read_csv("news.csv")
data.head()
# Out:
#           Company Name                                        Event Title  \
# 0  Reliance Industries       First Dividend Post-Bonus Issue Announcement
# 1  Reliance Industries                        Annual General Meeting 2025
# 2  Reliance Industries     Partnership with Google Cloud for AI Solutions
# 3  Reliance Industries  Institutional Investors Meeting - Goldman Sach...
# 4  Reliance Industries           Upcoming CITIC CLSA Investors Forum 2025
#
#                                                  URL        Date  \
# 0  https://www.angelone.in/news/market-updates/re...  2025-09-01
# 1  https://upstox.com/news/business-news/latest-u...  2025-08-29
# 2                                https://www.ril.com  2025-09-04
# 3  https://economictimes.com/reliance-industries-...  2025-09-04
# 4  https://economictimes.com/reliance-industries-...  2025-09-08
#
#                                    Event Description
# 0  Reliance Industries declared ₹5.50 dividend pe...
# 1  RIL AGM 2025 highlighted key announcements inc...
# 2  Reliance and Google Cloud expanded partnership...
# 3  Company executives participated in Goldman Sac...
# 4  RIL executives scheduled to participate in ins...

# %%
data.shape
# Out:
# (120, 5)

# %%
events = data["Event Description"]
# events.head(3)
events[119]
# Out:
# 'Bajaj Auto scheduled analyst conference call for September 2, 2025, for investor communication and business performance discussions.'

# %%
urls = data["URL"]
urls.head(3)
# Out:
# 0    https://www.angelone.in/news/market-updates/re...
# 1    https://upstox.com/news/business-news/latest-u...
# 2                                  https://www.ril.com
# Name: URL, dtype: object

# %%
# Make sure you have the required libraries installed:
# pip install transformers
# pip install torch
# pip install sentencepiece
# pip install requests
# pip install beautifulsoup4

from transformers import pipeline
import json
import requests
from bs4 import BeautifulSoup

def get_event_from_url(url, headline):
    """
    Fetches a news article from a URL, extracts the main event using an LLM,
    and returns the details in a JSON object.

    Args:
        url (str): The URL of the news article.
        headline (str): The headline of the news article.

    Returns:
        dict: A dictionary containing the URL, headline, and the extracted event.
              Returns an error dictionary if something goes wrong.
    """
    try:
        # 1. Fetch the article content from the web.
        print(f"Fetching article from: {url}...")
        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Raise an exception for bad status codes (4xx or 5xx)

        # 2. Parse the HTML and extract the main article text.
        # This part is generic and might need adjustments for different website structures.
        soup = BeautifulSoup(response.content, 'html.parser')
        paragraphs = soup.find_all('p')
        article_text = ' '.join([p.get_text() for p in paragraphs])

        if not article_text:
            return {"error": "Could not find any paragraph text on the page."}

        print("Article text extracted successfully.")

        # 3. Initialize the language model.
        print("Initializing the text-to-text generation model (flan-t5-base)...")
        extractor = pipeline('text2text-generation', model='google/pegasus-cnn_dailymail')
        print("Model initialized successfully.")

        # 4. Create a prompt to ask the model to extract the event.
        prompt = f"""
        Read the following news article and extract the main event described in it.

        Article: "{article_text}"

        Extracted Event:
        """

        # 5. Get the event from the model.
        print("Extracting the news event from the text...")
        outputs = extractor(prompt, max_new_tokens=512, clean_up_tokenization_spaces=True)
        event = outputs[0]['generated_text'].strip()
        print("Event extracted successfully.")

        # 6. Assemble and return the final JSON object.
        result = {
            "news_url": url,
            "news_headline": headline,
            "news_event": event
        }
        return result

    except requests.exceptions.RequestException as e:
        return {"error": f"Failed to fetch the URL: {e}"}
    except Exception as e:
        return {"error": f"An unexpected error occurred: {e}"}

# --- Example Usage ---
if __name__ == "__main__":
   for i in range(120):
    # You can change this URL and headline to any news article.
    sample_url = urls[i]
    sample_headline = events[i]

    # Get the structured event data
    event_data = get_event_from_url(sample_url, sample_headline)

    # Print the final, structured JSON object in a readable format
    print("\n--- Extracted Event (JSON Format) ---")
    print(json.dumps(event_data, indent=4))

# %%
from transformers import pipeline, AutoTokenizer
import json
import requests
from bs4 import BeautifulSoup

# Load model and tokenizer once
model_name = 'mrm8488/t5-base-finetuned-summarize-news'
extractor = pipeline('text2text-generation', model=model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
max_length = 512  # max tokens for flan-t5-base

def get_event_from_url(url, headline, extractor, tokenizer, max_length):
    try:
        print(f"Fetching article from: {url}...")
        headers = {'User-Agent': 'Mozilla/5.0'}
        response = requests.get(url, headers=headers)
        response.raise_for_status()

        soup = BeautifulSoup(response.content, 'html.parser')
        paragraphs = soup.find_all('p')
        article_text = ' '.join([p.get_text() for p in paragraphs])

        if not article_text:
            return {"news_url": url, "news_headline": headline, "error": "Could not find any paragraph text on the page."}

        # Truncate article text to max tokens for model input
        inputs = tokenizer(article_text, max_length=max_length, truncation=True, return_tensors="pt")
        truncated_text = tokenizer.decode(inputs['input_ids'][0], skip_special_tokens=True)

        prompt = f"""
        Read the following news article and extract the main event described in it.

        Article: "{truncated_text}"

        Extracted Event:
        """

        outputs = extractor(prompt, max_new_tokens=150)
        event = outputs[0]['generated_text'].strip()

        result = {
            "news_url": url,
            "news_headline": headline,
            "news_event": event
        }
        return result

    except requests.exceptions.RequestException as e:
        return {"news_url": url, "news_headline": headline, "error": f"Failed to fetch the URL: {e}"}
    except Exception as e:
        return {"news_url": url, "news_headline": headline, "error": f"An unexpected error occurred: {e}"}

if __name__ == "__main__":
    # Example lists; replace these with your actual URLs and headlines
    urls = urls
    events = events

    # Validate URLs to include only those with proper scheme
    valid_urls = [url for url in urls if url.startswith('http')]
    valid_headlines = [events[i] for i, url in enumerate(urls) if url.startswith('http')]

    all_event_data = []

    for i, sample_url in enumerate(valid_urls):
        sample_headline = valid_headlines[i]
        event_data = get_event_from_url(sample_url, sample_headline, extractor, tokenizer, max_length)
        print(json.dumps(event_data, indent=4))
        all_event_data.append(event_data)

    # Save all event data to JSON file
    with open("extracted_events.json", "w", encoding="utf-8") as f:
        json.dump(all_event_data, f, ensure_ascii=False, indent=2)

    print("All extracted events saved to extracted_events.json")
# Out:
# Device set to use cpu
# Fetching article from: https://www.angelone.in/news/market-updates/reliance-industries-dividend-2025-first-5-50-payout-post-bonus-issue-confirmed-at-agm...
# {
#     "news_url": "https://www.angelone.in/news/market-updates/reliance-industries-dividend-2025-first-5-50-payout-post-bonus-issue-confirmed-at-agm",
#     "news_headline": "Reliance Industries declared \u20b95.50 dividend per share for FY25, marking its first dividend after 1:1 bonus issue in October 2024, with overwhelming shareholder support of 99.9994%.",
#     "news_event": "Reliance Industries has announced its first dividend payout of 5.50 per share for FY 2024-25, marking its initial return following the 1:1 bonus issue in October 2024. The final dividend of 5.50 per equity share of 10 face value for the year ending March 31, 2025 will be declared within a week. The stock registered a gain of 1.37% over the past week. However, it has declined by 0.90% over the past month and 3 months.nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn"
# }
# Fetching article from: https://upstox.com/news/business-news/latest-updates/reliance-industries-agm-2025-live-updates...
# {
#     "news_url": "https://upstox.com/news/business-news/latest-updates/reliance-industries-agm-2025-live-updates",
#     "news_headline": "RIL AGM 2025 highlighted key announcements including Jio IPO timeline for H1 2026, AI strategy through Reliance Intelligence, and progress in new energy business.",
#     "error": "Failed to fetch the URL: 404 Client Error: Not Found for url: https://upstox.com/news/business-news/latest-updates/reliance-industries-agm-2025-live-updates/"
# }
# Fetching article from: https://www.ril.com...
# Token indices sequence length is longer than the specified maximum sequence length for this model (533 > 512). Running this sequence through the model will result in indexing errors
# {
#     "news_url": "https://www.ril.com",
#     "news_headline": "Reliance and Google Cloud expanded partnership to accelerate India's growth with AI, focusing on enterprise AI solutions and digital transformation.",
#     "news_event": "Reliance Retail is the largest producer of petrochemicals in the country and among the top 10 in the world. Jio, our digital services business, democratises access to digital services for millions of people. Reliance is committed to helping India achieve a net-zero carbon target by 2035. The media and entertainment business is pan-India."
# }
# Fetching article from: https://economictimes.com/reliance-industries-ltd/stocksupdate/companyid-13215.cms...
# {
#     "news_url": "https://economictimes.com/reliance-industries-ltd/stocksupdate/companyid-13215.cms",
#     "news_headline": "Company executives participated in Goldman Sachs conference with one-on-one investor meetings, with no unpublished price sensitive information shared.",
#     "news_event": "the combined market valuation of seven of the top-10 most valued firms jumped ?1,06,250.95 crore last week. Bajaj Finance and Reliance Industries emerged as the biggest gainers, in line with an optimistic trend in equities. Further, European diesel spreads are firm on lower imports after the EU announced a ban on refined product imports made from Russian crude starting January 21, 2026. The BSE Sensex opened higher.nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn"
# }
# Fetching article from: https://economictimes.com/reliance-industries-ltd/stocksupdate/companyid-13215.cms...
# {
#     "news_url": "https://economictimes.com/reliance-industries-ltd/stocksupdate/companyid-13215.cms",
#     "news_headline": "RIL executives scheduled to participate in institutional investor meetings at CITIC CLSA Investors Forum 2025 in Hong Kong.",
#     "news_event": "the combined market valuation of seven of the top-10 most valued firms jumped ?1,06,250.95 crore last week. Bajaj Finance and Reliance Industries emerged as the biggest gainers, in line with an optimistic trend in equities. Further, European diesel spreads are firm on lower imports after the EU announced a ban on refined product imports made from Russian crude starting January 21, 2026. The BSE Sensex opened higher.nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn"
# }
# Fetching article from: https://economictimes.com/reliance-industries-ltd/stocksupdate/companyid-13215.cms...
# {
#     "news_url": "https://economictimes.com/reliance-industries-ltd/stocksupdate/companyid-13215.cms",
#     "news_headline": "Mukesh Ambani announced Jio's mega IPO expected to be the 'mother of all IPOs', though RIL's 44 lakh shareholders may not get direct shares.",
#     "news_event": "the combined market valuation of seven of the top-10 most valued firms jumped ?1,06,250.95 crore last week. Bajaj Finance and Reliance Industries emerged as the biggest gainers, in line with an optimistic trend in equities. Further, European diesel spreads are firm on lower imports after the EU announced a ban on refined product imports made from Russian crude starting January 21, 2026. The BSE Sensex opened higher.nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn"
# }
# Fetching article from: https://scanx.trade/stock-market-news/corporate-actions/reliance-industries-boosts-stake-in-saavn-media-to-94-4-with-653-93-crore-investment...
# {
#     "news_url": "https://scanx.trade/stock-market-news/corporate-actions/reliance-industries-boosts-stake-in-saavn-media-to-94-4-with-653-93-crore-investment",
#     "news_headline": "Reliance Industries increased its stake in Saavn Media to 94.4% with \u20b9653.93 crore investment, strengthening its digital entertainment portfolio.",
#     "error": "Failed to fetch the URL: 403 Client Error: Forbidden for url: https://scanx.trade/stock-market-news/corporate-actions/reliance-industries-boosts-stake-in-saavn-media-to-94-4-with-653-93-crore-investment"
# }
# Fetching article from: https://www.polymerupdate.com/News/Details/1412449/ldpe...
# {
#     "news_url": "https://www.polymerupdate.com/News/Details/1412449/ldpe",
#     "news_headline": "RIL announced incentive scheme in Polyethylene (PE) for September 2025 in domestic markets of India, supporting petrochemical business growth.",
#     "news_event": "By clicking Accept , you provide your consent for use of cookies. If the cookies are disabled on your browser, please enable them from the Browser settings. Reload the page once the cookies are enabled. Copyright 1999 - 2025 Polymerupdate.com - Polymerupdate.com - Polymerupdate.com - Polymerupdate.com - Polymerupdate.com - Polymerupdate.com - Polymerupdate.com - Polymerupdate.com - Polymerupdate.com'"
# }
# Fetching article from: https://economictimes.com/reliance-industries-ltd/stocksupdate/companyid-13215.cms...
# {
#     "news_url": "https://economictimes.com/reliance-industries-ltd/stocksupdate/companyid-13215.cms",
#     "news_headline": "Morgan Stanley initiated coverage highlighting RIL as key beneficiary of China's anti-innovation push, supporting energy, solar, and consumer businesses.",
#     "news_event": "the combined market valuation of seven of the top-10 most valued firms jumped ?1,06,250.95 crore last week. Bajaj Finance and Reliance Industries emerged as the biggest gainers, in line with an optimistic trend in equities. Further, European diesel spreads are firm on lower imports after the EU announced a ban on refined product imports made from Russian crude starting January 21, 2026. The BSE Sensex opened higher.nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn"
# }
# Fetching article from: https://economictimes.com/reliance-industries-ltd/stocksupdate/companyid-13215.cms...
# {
#     "news_url": "https://economictimes.com/reliance-industries-ltd/stocksupdate/companyid-13215.cms",
#     "news_headline": "Company executives participated in Motilal Oswal 21st Annual Global Investor Conference in Mumbai with fund/investor one-on-one meetings.",
#     "news_event": "the combined market valuation of seven of the top-10 most valued firms jumped ?1,06,250.95 crore last week. Bajaj Finance and Reliance Industries emerged as the biggest gainers, in line with an optimistic trend in equities. Further, European diesel spreads are firm on lower imports after the EU announced a ban on refined product imports made from Russian crude starting January 21, 2026. The BSE Sensex opened higher.nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn"
# }
# Fetching article from: https://economictimes.com/reliance-industries-ltd/stocksupdate/companyid-13215.cms...
# {
#     "news_url": "https://economictimes.com/reliance-industries-ltd/stocksupdate/companyid-13215.cms",
#     "news_headline": "RIL's push into AI through Reliance Intelligence could be game changer for India, focusing on AI-powered enterprise solutions and growth.",
#     "news_event": "the combined market valuation of seven of the top-10 most valued firms jumped ?1,06,250.95 crore last week. Bajaj Finance and Reliance Industries emerged as the biggest gainers, in line with an optimistic trend in equities. Further, European diesel spreads are firm on lower imports after the EU announced a ban on refined product imports made from Russian crude starting January 21, 2026. The BSE Sensex opened higher.nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn"
# }
# Fetching article from: https://economictimes.com/reliance-industries-ltd/stocksupdate/companyid-13215.cms...
# {
#     "news_url": "https://economictimes.com/reliance-industries-ltd/stocksupdate/companyid-13215.cms",
#     "news_headline": "Significant progress reported in new energy business including solar and battery giga-factories, supporting India's clean energy transition.",
#     "news_event": "the combined market valuation of seven of the top-10 most valued firms jumped ?1,06,250.95 crore last week. Bajaj Finance and Reliance Industries emerged as the biggest gainers, in line with an optimistic trend in equities. Further, European diesel spreads are firm on lower imports after the EU announced a ban on refined product imports made from Russian crude starting January 21, 2026. The BSE Sensex opened higher.nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn"
# }
# Fetching article from: https://economictimes.com/reliance-industries-ltd/stocksupdate/companyid-13215.cms...
# {
#     "news_url": "https://economictimes.com/reliance-industries-ltd/stocksupdate/companyid-13215.cms",
#     "news_headline": "Jefferies report suggests RIL may earn $500 million annual EBITDA from Russian oil operations, with refining margins fueling real growth.",
#     "news_event": "the combined market valuation of seven of the top-10 most valued firms jumped ?1,06,250.95 crore last week. Bajaj Finance and Reliance Industries emerged as the biggest gainers, in line with an optimistic trend in equities. Further, European diesel spreads are firm on lower imports after the EU announced a ban on refined product imports made from Russian crude starting January 21, 2026. The BSE Sensex opened higher.nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn"
# }
# Fetching article from: https://economictimes.com/reliance-industries-ltd/stocksupdate/companyid-13215.cms...
# {
#     "news_url": "https://economictimes.com/reliance-industries-ltd/stocksupdate/companyid-13215.cms",
#     "news_headline": "RIL shares rose over 2% after two days of losses, driven by upbeat brokerage calls post-AGM and positive analyst recommendations.",
#     "news_event": "the combined market valuation of seven of the top-10 most valued firms jumped ?1,06,250.95 crore last week. Bajaj Finance and Reliance Industries emerged as the biggest gainers, in line with an optimistic trend in equities. Further, European diesel spreads are firm on lower imports after the EU announced a ban on refined product imports made from Russian crude starting January 21, 2026. The BSE Sensex opened higher.nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn"
# }
# Fetching article from: https://economictimes.com/reliance-industries-ltd/stocksupdate/companyid-13215.cms...
# {
#     "news_url": "https://economictimes.com/reliance-industries-ltd/stocksupdate/companyid-13215.cms",
#     "news_headline": "Joint media release by RIL and subsidiary Reliance Retail Limited announcing strategic initiatives and business developments.",
#     "news_event": "the combined market valuation of seven of the top-10 most valued firms jumped ?1,06,250.95 crore last week. Bajaj Finance and Reliance Industries emerged as the biggest gainers, in line with an optimistic trend in equities. Further, European diesel spreads are firm on lower imports after the EU announced a ban on refined product imports made from Russian crude starting January 21, 2026. The BSE Sensex opened higher.nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn"
# }
# Fetching article from: https://www.tcs.com/who-we-are/events/tcs-at-ibc-2025-amsterdam...
# {
#     "news_url": "https://www.tcs.com/who-we-are/events/tcs-at-ibc-2025-amsterdam",
#     "news_headline": "TCS showcasing AI-powered media and entertainment solutions at IBC 2025 in Amsterdam, focusing on seamless engagements and purposeful experiences.",
#     "news_event": "TCS invites you to IBC 2025, to explore how we're enabling global media and entertainment customers to reshape the value chain from storytelling to distribution, through the transformative power of AI and our intelligent digital transformation capabilities. The theme for the year is Seamless Engagements, Purposeful Experiences. TCS is a digital transformation and technology partner of choice for industry-leading organizations worldwide. Stay up-to-date on all press announcements by TCS."
# }
# Fetching article from: https://www.tcs.com/who-we-are/events/shaping-tomorrow-through-ai-cloud...
# {
#     "news_url": "https://www.tcs.com/who-we-are/events/shaping-tomorrow-through-ai-cloud",
#     "news_headline": "TCS hosting AI and cloud transformation event in Riyadh and Dubai, bringing together forward-thinking leaders to explore enterprise intelligence.",
#     "news_event": "'Shaping Tomorrow through AI' will be held in Dubai and Riyadh next month. The event will feature keynote talks, expert panels, and interactive discussions on how enterprises can unlock the full potential of cloud, data, and AI. \"With the best talent and latest technology, we help customers turn complexity into opportunities and create meaningful change,\" said TCS. The event will also feature a keynote address by TCS.nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn"
# }
# Fetching article from: https://tcsworld10k.procam.in/news-media/latest-news/world-s-premier-tata-consultancy-services-world-10-k-bengaluru-set-for-sunday-27th-april-2025...
# {
#     "news_url": "https://tcsworld10k.procam.in/news-media/latest-news/world-s-premier-tata-consultancy-services-world-10-k-bengaluru-set-for-sunday-27th-april-2025",
#     "news_headline": "17th edition of World Athletics Gold Label Road Race with USD 210,000 prize money, celebrating Bengaluru's spirit and promoting fitness and philanthropy.",
#     "news_event": "Tata Consultancy Services World 10K Bengaluru (TCS World 10K) is the 17th edition of the World Athletics Gold Label Road Race and the 17th edition of the Tata Consultancy Services World 10K Bengaluru. The race is a celebration of resilience, health, and community impact, offering a blend of competition, camaraderie, and community impact. Registration opens on Thursday, 20th February for all race categories. The TCS World 10K will be flagged off from Cubbon Road (oppo)."
# }
# Fetching article from: https://www.tcs.com/who-we-are/events/tcs-at-hpe-discover-2025...
# {
#     "news_url": "https://www.tcs.com/who-we-are/events/tcs-at-hpe-discover-2025",
#     "news_headline": "TCS as Gold Sponsor showcasing Intelligent Infrastructure for Adaptive Enterprise solutions at HPE Discover Showcase in Las Vegas.",
#     "news_event": "HPE Discover Las Vegas 2025 highlights include the TCS booth, \u201cIntelligent Infrastructure for Adaptive Enterprise\u201d. Visit the booth and connect with experts for in-depth discussions on our best-in-class integration solutions. Visit the HPE Discover Showcase to immerse yourself in the latest innovations across Gen AI, Agentic AI, and hybrid cloud. nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn"
# }
# Fetching article from: https://www.tcs.com/who-we-are/events/north-america-leadership-forum-2025...
# {
#     "news_url": "https://www.tcs.com/who-we-are/events/north-america-leadership-forum-2025",
#     "news_headline": "TCS and PTC presenting at Siemens Realize LIVE APAC 2025 in Bengaluru, focusing on AI-powered connected digital enterprises in manufacturing.",
#     "news_event": "Siemens Realize LIVE APAC 2025 is a leading digital transformation conference bringing together professionals from engineering, manufacturing, product design, product lifecycle management, and software. As a Premium Sponsor at the event, TCS is proud to lead the conversation on how digital technologies, AI, and automation are revolutionizing industry. Siemens Realize LIVE APAC 2025 will showcase how our integrated solutions enable Factories of the Future to become AI-led enterprises built for agility, efficiency, and growth."
# }
# Fetching article from: https://www.tcs.com/who-we-are/events/hannover-messe-2025...
# {
#     "news_url": "https://www.tcs.com/who-we-are/events/hannover-messe-2025",
#     "news_headline": "TCS team showcased next generation technologies reimagining future of manufacturing, demonstrating digital transformation solutions.",
#     "news_event": "Hannover Messe 2025 showcased TCS, a digital transformation and technology partner of choice for industry-leading organizations worldwide. With the best talent and latest technology, TCS helps customers turn complexity into opportunities and create meaningful change. Hannover Messe attracts over 5,500 exhibitors and over 200,000 trade visitors annually. Hannover Messe 2025 is the premier global event for industrial technology that showcases thought leadership, cutting-edge innovations, and industry expertise."
# }
# Fetching article from: https://www.tcs.com/who-we-are/events...
# {
#     "news_url": "https://www.tcs.com/who-we-are/events",
#     "news_headline": "TCS presenting banking and financial services solutions at SIBOS 2025 in Frankfurt, showcasing smart ledgers and financial technology innovations.",
#     "news_event": "At TCS, we don't just help businesses transform. We help them become perpetually adaptive enterprises, built to evolve continuously and confidently in a world of constant change. With the best talent and latest technology, we help customers turn complexity into opportunities and create meaningful change. At TCS, we believe exceptional work begins with hiring, celebrating and nurturing the best people \u2014 from all walks of life. Read the news article and extract the main event described in it."
# }
# Fetching article from: https://www.tcs.com/who-we-are/events...
# {
#     "news_url": "https://www.tcs.com/who-we-are/events",
#     "news_headline": "TCS hosting life sciences forum in London, bringing together healthcare and pharmaceutical industry leaders for transformation discussions.",
#     "news_event": "At TCS, we don't just help businesses transform. We help them become perpetually adaptive enterprises, built to evolve continuously and confidently in a world of constant change. With the best talent and latest technology, we help customers turn complexity into opportunities and create meaningful change. At TCS, we believe exceptional work begins with hiring, celebrating and nurturing the best people \u2014 from all walks of life. Read the news article and extract the main event described in it."
# }
# Fetching article from: https://www.tcs.com/who-we-are/events...
# {
#     "news_url": "https://www.tcs.com/who-we-are/events",
#     "news_headline": "TCS participating in manufacturing-focused aerospace summit, demonstrating digital transformation solutions for aviation industry.",
#     "news_event": "At TCS, we don't just help businesses transform. We help them become perpetually adaptive enterprises, built to evolve continuously and confidently in a world of constant change. With the best talent and latest technology, we help customers turn complexity into opportunities and create meaningful change. At TCS, we believe exceptional work begins with hiring, celebrating and nurturing the best people \u2014 from all walks of life. Read the news article and extract the main event described in it."
# }
# Fetching article from: https://www.tcs.com/who-we-are/events...
# {
#     "news_url": "https://www.tcs.com/who-we-are/events",
#     "news_headline": "TCS showcasing healthcare and life sciences solutions at Oracle summit, focusing on digital transformation in healthcare delivery.",
#     "news_event": "At TCS, we don't just help businesses transform. We help them become perpetually adaptive enterprises, built to evolve continuously and confidently in a world of constant change. With the best talent and latest technology, we help customers turn complexity into opportunities and create meaningful change. At TCS, we believe exceptional work begins with hiring, celebrating and nurturing the best people \u2014 from all walks of life. Read the news article and extract the main event described in it."
# }
# Fetching article from: https://www.tcs.com/who-we-are/events...
# {
#     "news_url": "https://www.tcs.com/who-we-are/events",
#     "news_headline": "TCS participating in premier cybersecurity conference, demonstrating advanced security solutions and threat intelligence capabilities.",
#     "news_event": "At TCS, we don't just help businesses transform. We help them become perpetually adaptive enterprises, built to evolve continuously and confidently in a world of constant change. With the best talent and latest technology, we help customers turn complexity into opportunities and create meaningful change. At TCS, we believe exceptional work begins with hiring, celebrating and nurturing the best people \u2014 from all walks of life. Read the news article and extract the main event described in it."
# }
# Fetching article from: https://www.tcs.com/who-we-are/events...
# {
#     "news_url": "https://www.tcs.com/who-we-are/events",
#     "news_headline": "TCS at DVCon India 2025 focusing on shaping future of semiconductors with high-tech solutions and manufacturing excellence.",
#     "news_event": "At TCS, we don't just help businesses transform. We help them become perpetually adaptive enterprises, built to evolve continuously and confidently in a world of constant change. With the best talent and latest technology, we help customers turn complexity into opportunities and create meaningful change. At TCS, we believe exceptional work begins with hiring, celebrating and nurturing the best people \u2014 from all walks of life. Read the news article and extract the main event described in it."
# }
# Fetching article from: https://www.tcs.com/who-we-are/events...
# {
#     "news_url": "https://www.tcs.com/who-we-are/events",
#     "news_headline": "TCS showcasing cognitive business operations solutions at Customer Contact Week, demonstrating AI-powered customer service transformation.",
#     "news_event": "At TCS, we don't just help businesses transform. We help them become perpetually adaptive enterprises, built to evolve continuously and confidently in a world of constant change. With the best talent and latest technology, we help customers turn complexity into opportunities and create meaningful change. At TCS, we believe exceptional work begins with hiring, celebrating and nurturing the best people \u2014 from all walks of life. Read the news article and extract the main event described in it."
# }
# Fetching article from: https://www.tcs.com/who-we-are/events...
# {
#     "news_url": "https://www.tcs.com/who-we-are/events",
#     "news_headline": "TCS conducting specialized webinar on banking and tax information reporting solutions, focusing on regulatory compliance and automation.",
#     "news_event": "At TCS, we don't just help businesses transform. We help them become perpetually adaptive enterprises, built to evolve continuously and confidently in a world of constant change. With the best talent and latest technology, we help customers turn complexity into opportunities and create meaningful change. At TCS, we believe exceptional work begins with hiring, celebrating and nurturing the best people \u2014 from all walks of life. Read the news article and extract the main event described in it."
# }
# Fetching article from: https://www.tcs.com/who-we-are/events...
# {
#     "news_url": "https://www.tcs.com/who-we-are/events",
#     "news_headline": "TCS presenting drug safety and pharmaceutical solutions at premier Americas congress, showcasing ADD platform for healthcare transformation.",
#     "news_event": "At TCS, we don't just help businesses transform. We help them become perpetually adaptive enterprises, built to evolve continuously and confidently in a world of constant change. With the best talent and latest technology, we help customers turn complexity into opportunities and create meaningful change. At TCS, we believe exceptional work begins with hiring, celebrating and nurturing the best people \u2014 from all walks of life. Read the news article and extract the main event described in it."
# }
# Fetching article from: https://upstox.com/news/market-news/stocks/hdfc-bank-confident-of-growing-advances-on-par-with-industry-in-2025-26-fiscal-year...
# {
#     "news_url": "https://upstox.com/news/market-news/stocks/hdfc-bank-confident-of-growing-advances-on-par-with-industry-in-2025-26-fiscal-year",
#     "news_headline": "HDFC Bank reported healthy growth while maintaining pristine asset quality, with CEO expressing confidence in growing advances on par with industry in FY26.",
#     "error": "Failed to fetch the URL: 404 Client Error: Not Found for url: https://upstox.com/news/market-news/stocks/hdfc-bank-confident-of-growing-advances-on-par-with-industry-in-2025-26-fiscal-year/"
# }
# Fetching article from: https://economictimes.com/industry/banking/finance/banking/hdfc-merger-continues-to-remain-a-drag-on-bank-credit-growth...
# {
#     "news_url": "https://economictimes.com/industry/banking/finance/banking/hdfc-merger-continues-to-remain-a-drag-on-bank-credit-growth",
#     "news_headline": "HDFC merger impact on credit growth discussed, with focus on balancing growth while ensuring stability in banking system post-integration.",
#     "error": "Failed to fetch the URL: 404 Client Error: Not Found for url: https://economictimes.indiatimes.com/industry/banking/finance/banking/hdfc-merger-continues-to-remain-a-drag-on-bank-credit-growth"
# }
# Fetching article from: https://www.kotaksecurities.com/news/market-news/hdfc-bank-first-bonus-share-issue...
# {
#     "news_url": "https://www.kotaksecurities.com/news/market-news/hdfc-bank-first-bonus-share-issue",
#     "news_headline": "HDFC Bank board to consider first-ever bonus share issue, marking significant milestone in bank's corporate action history.",
#     "news_event": "HDFC Bank, India's largest private-sector lender by market capitalization, will hold a board meeting on July 19, 2025. The board is expected to consider recommending a bonus share issuance, along with declaring a special interim dividend for the 2025\u201326 fiscal year. Additional shares granted to existing shareholders without any cost, proportionate to their current holdings. Notably, HDFC Bank remains a heavyweight in the Nifty index. Over the past year, the stock has climbed 23%. Notably,"
# }
# Fetching article from: https://www.hdfcbank.com/personal/about-us/news-room/press-release/2025/q2/hdfc-bank-was-adjudged-%E2%80%98india%E2%80%99s-best-for-hnw%E2%80%99-at-euromoney-private-banking-awards-2025...
# {
#     "news_url": "https://www.hdfcbank.com/personal/about-us/news-room/press-release/2025/q2/hdfc-bank-was-adjudged-%E2%80%98india%E2%80%99s-best-for-hnw%E2%80%99-at-euromoney-private-banking-awards-2025",
#     "news_headline": "HDFC Bank won 'India's Best for HNW' at Euromoney Private Banking Awards 2025, recognized for Imperia programme and SmartWealth platform launch.",
#     "news_event": "HDFC Bank was adjudged as \u2018India's Best for High Net Worth (HNW) at the Euromoney Private Banking Awards 2025. HDFC Bank's digital platform SmartWealth provides clients with the ability to track portfolios, execute investments and access goal-based investment recommendations. \"We believe that we are in the business of preserving client's wealth, ensuring its growth and retaining their trust,\" said Rakesh Singh, Group Head - Investment Banking. The awards were organized by Euromoney.nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn"
# }
# Fetching article from: https://www.hdfcbank.com/content/bbp/repositories/723fb80a-2dde-42a3-9793-7ae1be57c87f...
# {
#     "news_url": "https://www.hdfcbank.com/content/bbp/repositories/723fb80a-2dde-42a3-9793-7ae1be57c87f",
#     "news_headline": "Gross advances reached \u20b926,532 billion as of June 30, 2025, showing 6.7% increase over previous year with strategic focus on quality growth.",
#     "error": "Failed to fetch the URL: 400 Client Error: Bad Request for url: https://www.hdfcbank.com/content/bbp/repositories/723fb80a-2dde-42a3-9793-7ae1be57c87f"
# }
# Fetching article from: https://upstox.com/news/market-news/stocks/hdfc-bank-confident-of-growing-advances-on-par-with-industry-in-2025-26-fiscal-year...
# {
#     "news_url": "https://upstox.com/news/market-news/stocks/hdfc-bank-confident-of-growing-advances-on-par-with-industry-in-2025-26-fiscal-year",
#     "news_headline": "Bank successfully brought down credit-deposit ratio to 96% from 110% post-merger, with high-cost borrowings reduced to 14%.",
#     "error": "Failed to fetch the URL: 404 Client Error: Not Found for url: https://upstox.com/news/market-news/stocks/hdfc-bank-confident-of-growing-advances-on-par-with-industry-in-2025-26-fiscal-year/"
# }
# Fetching article from: https://www.hdfcbank.com/personal/about-us/news-room/press-release/2025/q2/hdfc-bank-was-adjudged-%E2%80%98india%E2%80%99s-best-for-hnw%E2%80%99-at-euromoney-private-banking-awards-2025...
# {
#     "news_url": "https://www.hdfcbank.com/personal/about-us/news-room/press-release/2025/q2/hdfc-bank-was-adjudged-%E2%80%98india%E2%80%99s-best-for-hnw%E2%80%99-at-euromoney-private-banking-awards-2025",
#     "news_headline": "Launch of SmartWealth platform for mass-affluent segment with mobile investment services, portfolio tracking, and goal-based recommendations.",
#     "news_event": "HDFC Bank was adjudged as \u2018India's Best for High Net Worth (HNW) at the Euromoney Private Banking Awards 2025. HDFC Bank's digital platform SmartWealth provides clients with the ability to track portfolios, execute investments and access goal-based investment recommendations. \"We believe that we are in the business of preserving client's wealth, ensuring its growth and retaining their trust,\" said Rakesh Singh, Group Head - Investment Banking. The awards were organized by Euromoney.nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn"
# }
# Fetching article from: https://upstox.com/news/market-news/stocks/hdfc-bank-confident-of-growing-advances-on-par-with-industry-in-2025-26-fiscal-year...
# {
#     "news_url": "https://upstox.com/news/market-news/stocks/hdfc-bank-confident-of-growing-advances-on-par-with-industry-in-2025-26-fiscal-year",
#     "news_headline": "Bank maintained pristine asset quality with Gross NPAs at 1.33% of advances, demonstrating strong risk management capabilities.",
#     "error": "Failed to fetch the URL: 404 Client Error: Not Found for url: https://upstox.com/news/market-news/stocks/hdfc-bank-confident-of-growing-advances-on-par-with-industry-in-2025-26-fiscal-year/"
# }
# Fetching article from: https://upstox.com/news/market-news/stocks/hdfc-bank-confident-of-growing-advances-on-par-with-industry-in-2025-26-fiscal-year...
# {
#     "news_url": "https://upstox.com/news/market-news/stocks/hdfc-bank-confident-of-growing-advances-on-par-with-industry-in-2025-26-fiscal-year",
#     "news_headline": "Bank achieved 11% market share of banking deposits with only 5% branch market share, demonstrating superior deposit mobilization efficiency.",
#     "error": "Failed to fetch the URL: 404 Client Error: Not Found for url: https://upstox.com/news/market-news/stocks/hdfc-bank-confident-of-growing-advances-on-par-with-industry-in-2025-26-fiscal-year/"
# }
# Fetching article from: https://upstox.com/news/market-news/stocks/hdfc-bank-confident-of-growing-advances-on-par-with-industry-in-2025-26-fiscal-year...
# {
#     "news_url": "https://upstox.com/news/market-news/stocks/hdfc-bank-confident-of-growing-advances-on-par-with-industry-in-2025-26-fiscal-year",
#     "news_headline": "Enhanced information security posture through strategic and technology-driven initiatives to strengthen resilience against cyber threats.",
#     "error": "Failed to fetch the URL: 404 Client Error: Not Found for url: https://upstox.com/news/market-news/stocks/hdfc-bank-confident-of-growing-advances-on-par-with-industry-in-2025-26-fiscal-year/"
# }
# Fetching article from: https://upstox.com/news/market-news/stocks/hdfc-bank-confident-of-growing-advances-on-par-with-industry-in-2025-26-fiscal-year...
# {
#     "news_url": "https://upstox.com/news/market-news/stocks/hdfc-bank-confident-of-growing-advances-on-par-with-industry-in-2025-26-fiscal-year",
#     "news_headline": "FY25 results represented first full year of operations since merger on July 1, 2023, showing successful integration and growth trajectory.",
#     "error": "Failed to fetch the URL: 404 Client Error: Not Found for url: https://upstox.com/news/market-news/stocks/hdfc-bank-confident-of-growing-advances-on-par-with-industry-in-2025-26-fiscal-year/"
# }
# Fetching article from: https://upstox.com/news/market-news/stocks/hdfc-bank-confident-of-growing-advances-on-par-with-industry-in-2025-26-fiscal-year...
# {
#     "news_url": "https://upstox.com/news/market-news/stocks/hdfc-bank-confident-of-growing-advances-on-par-with-industry-in-2025-26-fiscal-year",
#     "news_headline": "Bank reported net profit of \u20b967,347.4 crore in March 2025 quarter, surging 10.7% year-on-year with strong operational performance.",
#     "error": "Failed to fetch the URL: 404 Client Error: Not Found for url: https://upstox.com/news/market-news/stocks/hdfc-bank-confident-of-growing-advances-on-par-with-industry-in-2025-26-fiscal-year/"
# }
# Fetching article from: https://upstox.com/news/market-news/stocks/hdfc-bank-confident-of-growing-advances-on-par-with-industry-in-2025-26-fiscal-year...
# {
#     "news_url": "https://upstox.com/news/market-news/stocks/hdfc-bank-confident-of-growing-advances-on-par-with-industry-in-2025-26-fiscal-year",
#     "news_headline": "Bank's balance sheet rose by over 8% to \u20b939,10,199 crore, demonstrating strong growth trajectory post-merger integration.",
#     "error": "Failed to fetch the URL: 404 Client Error: Not Found for url: https://upstox.com/news/market-news/stocks/hdfc-bank-confident-of-growing-advances-on-par-with-industry-in-2025-26-fiscal-year/"
# }
# Fetching article from: https://upstox.com/news/market-news/stocks/hdfc-bank-confident-of-growing-advances-on-par-with-industry-in-2025-26-fiscal-year...
# {
#     "news_url": "https://upstox.com/news/market-news/stocks/hdfc-bank-confident-of-growing-advances-on-par-with-industry-in-2025-26-fiscal-year",
#     "news_headline": "Bank garnered approximately 14.6% incremental deposit market share in FY25, showcasing competitive strength in deposit mobilization.",
#     "error": "Failed to fetch the URL: 404 Client Error: Not Found for url: https://upstox.com/news/market-news/stocks/hdfc-bank-confident-of-growing-advances-on-par-with-industry-in-2025-26-fiscal-year/"
# }
# Fetching article from: https://upstox.com/news/market-news/stocks/hdfc-bank-confident-of-growing-advances-on-par-with-industry-in-2025-26-fiscal-year...
# {
#     "news_url": "https://upstox.com/news/market-news/stocks/hdfc-bank-confident-of-growing-advances-on-par-with-industry-in-2025-26-fiscal-year",
#     "news_headline": "CEO announced confidence in growing advances on par with system in FY26 and higher than system in FY27, outlining ambitious growth plans.",
#     "error": "Failed to fetch the URL: 404 Client Error: Not Found for url: https://upstox.com/news/market-news/stocks/hdfc-bank-confident-of-growing-advances-on-par-with-industry-in-2025-26-fiscal-year/"
# }
# Fetching article from: https://economictimes.indiatimes.com/infosys-ltd/stocksupdate/companyid-10960.cms...
# {
#     "news_url": "https://economictimes.indiatimes.com/infosys-ltd/stocksupdate/companyid-10960.cms",
#     "news_headline": "Infosys partnered with Mastercard to streamline cross-border payments, enabling faster, more secure onboarding for banks and boosting payment integration efficiency.",
#     "news_event": "the combined market valuation of seven of the top-10 most valued firms jumped ?1,06,250.95 crore last week, with Bajaj Finance and Reliance Industries emerging as the biggest gainers, in line with an optimistic trend in equities. Indian benchmark indices Sensex and Nifty experienced a third consecutive session of declines on Wednesday, primarily influenced by the downturn in banking and IT sectors. Notably, Infosys has partnered with Mastercard to streamline cross-border payments."
# }
# Fetching article from: https://economictimes.indiatimes.com/infosys-ltd/stocksupdate/companyid-10960.cms...
# {
#     "news_url": "https://economictimes.indiatimes.com/infosys-ltd/stocksupdate/companyid-10960.cms",
#     "news_headline": "Infosys acquired 75% stake in Australia's Versent Group for AUD 233.25 million to strengthen presence in cloud and AI services market.",
#     "news_event": "the combined market valuation of seven of the top-10 most valued firms jumped ?1,06,250.95 crore last week, with Bajaj Finance and Reliance Industries emerging as the biggest gainers, in line with an optimistic trend in equities. Indian benchmark indices Sensex and Nifty experienced a third consecutive session of declines on Wednesday, primarily influenced by the downturn in banking and IT sectors. Notably, Infosys has partnered with Mastercard to streamline cross-border payments."
# }
# Fetching article from: https://economictimes.indiatimes.com/infosys-ltd/stocksupdate/companyid-10960.cms...
# {
#     "news_url": "https://economictimes.indiatimes.com/infosys-ltd/stocksupdate/companyid-10960.cms",
#     "news_headline": "Infosys transformed ABN AMRO's lending process with nCino platform implementation, enhancing banking operational efficiency and customer experience.",
#     "news_event": "the combined market valuation of seven of the top-10 most valued firms jumped ?1,06,250.95 crore last week, with Bajaj Finance and Reliance Industries emerging as the biggest gainers, in line with an optimistic trend in equities. Indian benchmark indices Sensex and Nifty experienced a third consecutive session of declines on Wednesday, primarily influenced by the downturn in banking and IT sectors. Notably, Infosys has partnered with Mastercard to streamline cross-border payments."
# }
# Fetching article from: https://economictimes.indiatimes.com/infosys-ltd/stocksupdate/companyid-10960.cms...
# {
#     "news_url": "https://economictimes.indiatimes.com/infosys-ltd/stocksupdate/companyid-10960.cms",
#     "news_headline": "Infosys collaborated with Glion Arena Kobe as official Digital Innovation and GX (Green Transformation) partner, focusing on sustainable digital solutions.",
#     "news_event": "the combined market valuation of seven of the top-10 most valued firms jumped ?1,06,250.95 crore last week, with Bajaj Finance and Reliance Industries emerging as the biggest gainers, in line with an optimistic trend in equities. Indian benchmark indices Sensex and Nifty experienced a third consecutive session of declines on Wednesday, primarily influenced by the downturn in banking and IT sectors. Notably, Infosys has partnered with Mastercard to streamline cross-border payments."
# }
# Fetching article from: https://economictimes.indiatimes.com/infosys-ltd/stocksupdate/companyid-10960.cms...
# {
#     "news_url": "https://economictimes.indiatimes.com/infosys-ltd/stocksupdate/companyid-10960.cms",
#     "news_headline": "Infosys announced allotment of Employee Stock Ownership Plans (ESOPs) as part of employee retention and incentive strategy.",
#     "news_event": "the combined market valuation of seven of the top-10 most valued firms jumped ?1,06,250.95 crore last week, with Bajaj Finance and Reliance Industries emerging as the biggest gainers, in line with an optimistic trend in equities. Indian benchmark indices Sensex and Nifty experienced a third consecutive session of declines on Wednesday, primarily influenced by the downturn in banking and IT sectors. Notably, Infosys has partnered with Mastercard to streamline cross-border payments."
# }
# Fetching article from: https://economictimes.indiatimes.com/infosys-ltd/stocksupdate/companyid-10960.cms...
# {
#     "news_url": "https://economictimes.indiatimes.com/infosys-ltd/stocksupdate/companyid-10960.cms",
#     "news_headline": "Infosys released report showing 86% of enterprises anticipate heightened AI risks, while only 2% meet responsible AI standards as Agentic AI gains traction.",
#     "news_event": "the combined market valuation of seven of the top-10 most valued firms jumped ?1,06,250.95 crore last week, with Bajaj Finance and Reliance Industries emerging as the biggest gainers, in line with an optimistic trend in equities. Indian benchmark indices Sensex and Nifty experienced a third consecutive session of declines on Wednesday, primarily influenced by the downturn in banking and IT sectors. Notably, Infosys has partnered with Mastercard to streamline cross-border payments."
# }
# Fetching article from: https://economictimes.indiatimes.com/infosys-ltd/stocksupdate/companyid-10960.cms...
# {
#     "news_url": "https://economictimes.indiatimes.com/infosys-ltd/stocksupdate/companyid-10960.cms",
#     "news_headline": "Infosys entered joint venture agreement with Telstra Limited, expanding strategic partnerships in telecommunications and digital transformation.",
#     "news_event": "the combined market valuation of seven of the top-10 most valued firms jumped ?1,06,250.95 crore last week, with Bajaj Finance and Reliance Industries emerging as the biggest gainers, in line with an optimistic trend in equities. Indian benchmark indices Sensex and Nifty experienced a third consecutive session of declines on Wednesday, primarily influenced by the downturn in banking and IT sectors. Notably, Infosys has partnered with Mastercard to streamline cross-border payments."
# }
# Fetching article from: https://economictimes.indiatimes.com/infosys-ltd/stocksupdate/companyid-10960.cms...
# {
#     "news_url": "https://economictimes.indiatimes.com/infosys-ltd/stocksupdate/companyid-10960.cms",
#     "news_headline": "Uniting Financial Services, Australia subscribed to Infosys Finacle's Digital Banking SaaS Suite on AWS Cloud, enhancing financial services delivery.",
#     "news_event": "the combined market valuation of seven of the top-10 most valued firms jumped ?1,06,250.95 crore last week, with Bajaj Finance and Reliance Industries emerging as the biggest gainers, in line with an optimistic trend in equities. Indian benchmark indices Sensex and Nifty experienced a third consecutive session of declines on Wednesday, primarily influenced by the downturn in banking and IT sectors. Notably, Infosys has partnered with Mastercard to streamline cross-border payments."
# }
# Fetching article from: https://economictimes.indiatimes.com/infosys-ltd/stocksupdate/companyid-10960.cms...
# {
#     "news_url": "https://economictimes.indiatimes.com/infosys-ltd/stocksupdate/companyid-10960.cms",
#     "news_headline": "Investec upgraded Infosys to 'Buy' with target price of \u20b91,655, anticipating 8% gain and improved risk-reward scenario for IT services stocks.",
#     "news_event": "the combined market valuation of seven of the top-10 most valued firms jumped ?1,06,250.95 crore last week, with Bajaj Finance and Reliance Industries emerging as the biggest gainers, in line with an optimistic trend in equities. Indian benchmark indices Sensex and Nifty experienced a third consecutive session of declines on Wednesday, primarily influenced by the downturn in banking and IT sectors. Notably, Infosys has partnered with Mastercard to streamline cross-border payments."
# }
# Fetching article from: https://economictimes.indiatimes.com/infosys-ltd/stocksupdate/companyid-10960.cms...
# {
#     "news_url": "https://economictimes.indiatimes.com/infosys-ltd/stocksupdate/companyid-10960.cms",
#     "news_headline": "Infosys revised revenue guidance for Q1 FY26, reflecting demand challenges in IT sector while maintaining focus on AI-led transformation initiatives.",
#     "news_event": "the combined market valuation of seven of the top-10 most valued firms jumped ?1,06,250.95 crore last week, with Bajaj Finance and Reliance Industries emerging as the biggest gainers, in line with an optimistic trend in equities. Indian benchmark indices Sensex and Nifty experienced a third consecutive session of declines on Wednesday, primarily influenced by the downturn in banking and IT sectors. Notably, Infosys has partnered with Mastercard to streamline cross-border payments."
# }
# Fetching article from: https://economictimes.indiatimes.com/infosys-ltd/stocksupdate/companyid-10960.cms...
# {
#     "news_url": "https://economictimes.indiatimes.com/infosys-ltd/stocksupdate/companyid-10960.cms",
#     "news_headline": "Infosys shares gained over 3% following analyst upgrades citing long-term IT resilience and recovery expected in H2 FY26 driven by AI transformation.",
#     "news_event": "the combined market valuation of seven of the top-10 most valued firms jumped ?1,06,250.95 crore last week, with Bajaj Finance and Reliance Industries emerging as the biggest gainers, in line with an optimistic trend in equities. Indian benchmark indices Sensex and Nifty experienced a third consecutive session of declines on Wednesday, primarily influenced by the downturn in banking and IT sectors. Notably, Infosys has partnered with Mastercard to streamline cross-border payments."
# }
# Fetching article from: https://economictimes.indiatimes.com/infosys-ltd/stocksupdate/companyid-10960.cms...
# {
#     "news_url": "https://economictimes.indiatimes.com/infosys-ltd/stocksupdate/companyid-10960.cms",
#     "news_headline": "Infosys shares rallied on Fed Chair Jerome Powell's rate cut signals, with Indian IT stocks benefiting from potential US monetary policy easing.",
#     "news_event": "the combined market valuation of seven of the top-10 most valued firms jumped ?1,06,250.95 crore last week, with Bajaj Finance and Reliance Industries emerging as the biggest gainers, in line with an optimistic trend in equities. Indian benchmark indices Sensex and Nifty experienced a third consecutive session of declines on Wednesday, primarily influenced by the downturn in banking and IT sectors. Notably, Infosys has partnered with Mastercard to streamline cross-border payments."
# }
# Fetching article from: https://economictimes.indiatimes.com/infosys-ltd/stocksupdate/companyid-10960.cms...
# {
#     "news_url": "https://economictimes.indiatimes.com/infosys-ltd/stocksupdate/companyid-10960.cms",
#     "news_headline": "Infosys among firms with increased market valuation, benefiting from renewed buying interest in IT stocks amid tariff clarity and confidence boost.",
#     "news_event": "the combined market valuation of seven of the top-10 most valued firms jumped ?1,06,250.95 crore last week, with Bajaj Finance and Reliance Industries emerging as the biggest gainers, in line with an optimistic trend in equities. Indian benchmark indices Sensex and Nifty experienced a third consecutive session of declines on Wednesday, primarily influenced by the downturn in banking and IT sectors. Notably, Infosys has partnered with Mastercard to streamline cross-border payments."
# }
# Fetching article from: https://economictimes.indiatimes.com/infosys-ltd/stocksupdate/companyid-10960.cms...
# {
# ...
# }
# Fetching article from: https://economictimes.com/news/company/corporate-trends/adani-agm-2025-key-highlights-outcome-airport-green-energy-adani-ports-shipping-shares-gautam-adani-speech...
# {
#     "news_url": "https://economictimes.com/news/company/corporate-trends/adani-agm-2025-key-highlights-outcome-airport-green-energy-adani-ports-shipping-shares-gautam-adani-speech",
#     "news_headline": "Adani Green building world's largest renewable energy park visible from space, targeting 50 GW by 2030 with 100 GW total capacity goal.",
#     "error": "Failed to fetch the URL: 404 Client Error: Not Found for url: https://economictimes.indiatimes.com/news/company/corporate-trends/adani-agm-2025-key-highlights-outcome-airport-green-energy-adani-ports-shipping-shares-gautam-adani-speech"
# }
# Fetching article from: https://economictimes.com/news/company/corporate-trends/adani-agm-2025-key-highlights-outcome-airport-green-energy-adani-ports-shipping-shares-gautam-adani-speech...
# {
#     "news_url": "https://economictimes.com/news/company/corporate-trends/adani-agm-2025-key-highlights-outcome-airport-green-energy-adani-ports-shipping-shares-gautam-adani-speech",
#     "news_headline": "Adani Ports handled record 450 MMT cargo supporting PM's Gati Shakti Mission, powering MSME exports and reducing friction for global competitiveness.",
#     "error": "Failed to fetch the URL: 404 Client Error: Not Found for url: https://economictimes.indiatimes.com/news/company/corporate-trends/adani-agm-2025-key-highlights-outcome-airport-green-energy-adani-ports-shipping-shares-gautam-adani-speech"
# }
# Fetching article from: https://economictimes.indiatimes.com/topic/adani-group...
# {
#     "news_url": "https://economictimes.indiatimes.com/topic/adani-group",
#     "news_headline": "Adani units raised $275 million through foreign currency loans with increased investor confidence, supporting bond buybacks and capex plans.",
#     "news_event": "Jaiprakash Associates, facing insolvency proceedings due to loan defaults, has been acquired by Vedanta Group, surpassing Gautam Adani's Group. Vedanta's 17,000-crore offer translated to a net present value of ?12,505 crore. The deal involves major cement facilities. No binding offers were submitted for the deal.nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn"
# }
# Fetching article from: https://economictimes.indiatimes.com/topic/adani-group...
# {
#     "news_url": "https://economictimes.indiatimes.com/topic/adani-group",
#     "news_headline": "Adani's Vizhinjam International Seaport achieved major milestone handling over 1 million TEUs in nine months, welcoming 460+ vessels since launch.",
#     "news_event": "Jaiprakash Associates, facing insolvency proceedings due to loan defaults, has been acquired by Vedanta Group, surpassing Gautam Adani's Group. Vedanta's 17,000-crore offer translated to a net present value of ?12,505 crore. The deal involves major cement facilities. No binding offers were submitted for the deal.nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn"
# }
# Fetching article from: https://economictimes.indiatimes.com/topic/adani-group...
# {
#     "news_url": "https://economictimes.indiatimes.com/topic/adani-group",
#     "news_headline": "Adani Enterprises reported 45% profit drop to \u20b9976.48 crore in Q1 FY26 despite revenue growth, reflecting operational adjustments and market conditions.",
#     "news_event": "Jaiprakash Associates, facing insolvency proceedings due to loan defaults, has been acquired by Vedanta Group, surpassing Gautam Adani's Group. Vedanta's 17,000-crore offer translated to a net present value of ?12,505 crore. The deal involves major cement facilities. No binding offers were submitted for the deal.nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn"
# }
# Fetching article from: https://www.bajajauto.com/corporate/media-centre/press-releases/the-worlds-first-cng-motorcycle-bajaj-freedom-125-showcased-at-the-bharat-mobility-expo-2025...
# {
#     "news_url": "https://www.bajajauto.com/corporate/media-centre/press-releases/the-worlds-first-cng-motorcycle-bajaj-freedom-125-showcased-at-the-bharat-mobility-expo-2025",
#     "news_headline": "Bajaj showcased world's first CNG motorcycle Bajaj Freedom 125 at Bharat Mobility Expo 2025, launched in July 2024 for sustainable mobility.",
#     "news_event": "Bajaj Auto, the world's most valuable two-wheeler and three-wheeler company, today showcased the Bajaj Freedom 125, the world's first CNG motorcycle, at the Bharat Mobility Expo 2025. Launched in July 2024, the Freedom 125 is a testament to India's innovation, research, and manufacturing capabilities. The Bharat Mobility Expo 2025 is India's seminal Auto Expo, and a prestigious platform."
# }
# Fetching article from: https://economictimes.indiatimes.com/bajaj-auto-ltd/stocksupdate/companyid-21430.cms...
# {
#     "news_url": "https://economictimes.indiatimes.com/bajaj-auto-ltd/stocksupdate/companyid-21430.cms",
#     "news_headline": "Bajaj Auto held 18th AGM with voting results and scrutinizer's report, addressing shareholder resolutions and corporate governance matters.",
#     "news_event": "Bajaj Auto, M&M, Tata Motors, and Eicher Motors lifted the Nifty Auto index by 2.8% on Monday. Bajaj Auto's sales of 4,17,616 units in August 2025, up from 3,97,804 units a year earlier, and Tata Motors' sales of 18,94,853 units versus 18,54,029 last year. Oil prices edged higher despite demand concerns related to U.S. tariffs.nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn"
# }
# Fetching article from: https://economictimes.indiatimes.com/bajaj-auto-ltd/stocksupdate/companyid-21430.cms...
# {
#     "news_url": "https://economictimes.indiatimes.com/bajaj-auto-ltd/stocksupdate/companyid-21430.cms",
#     "news_headline": "Bajaj Auto reported 14% YoY rise in Q1FY26 PAT to \u20b92,210 crore with revenue growth of 10% to \u20b913,133 crore driven by exports and premium sales.",
#     "news_event": "Bajaj Auto, M&M, Tata Motors, and Eicher Motors lifted the Nifty Auto index by 2.8% on Monday. Bajaj Auto's sales of 4,17,616 units in August 2025, up from 3,97,804 units a year earlier, and Tata Motors' sales of 18,94,853 units versus 18,54,029 last year. Oil prices edged higher despite demand concerns related to U.S. tariffs.nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn"
# }
# Fetching article from: https://economictimes.indiatimes.com/bajaj-auto-ltd/stocksupdate/companyid-21430.cms...
# {
#     "news_url": "https://economictimes.indiatimes.com/bajaj-auto-ltd/stocksupdate/companyid-21430.cms",
#     "news_headline": "Bajaj Auto overcame global magnet supply challenges with Chetak electric scooter deliveries resuming ahead of plan for festive season.",
#     "news_event": "Bajaj Auto, M&M, Tata Motors, and Eicher Motors lifted the Nifty Auto index by 2.8% on Monday. Bajaj Auto's sales of 4,17,616 units in August 2025, up from 3,97,804 units a year earlier, and Tata Motors' sales of 18,94,853 units versus 18,54,029 last year. Oil prices edged higher despite demand concerns related to U.S. tariffs.nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn"
# }
# Fetching article from: https://www.angelone.in/news/stocks-share-market/bajaj-auto-final-dividend-record-date-today-june-20-2025-how-much-will-1000-shares-earn...
# {
#     "news_url": "https://www.angelone.in/news/stocks-share-market/bajaj-auto-final-dividend-record-date-today-june-20-2025-how-much-will-1000-shares-earn",
#     "news_headline": "Bajaj Auto's \u20b9210 per share final dividend with record date June 20, 2025, providing significant returns for shareholders.",
#     "news_event": "Bajaj Auto has announced a final dividend of 210 per share for the financial year 2025. To be eligible for the dividend, you must be a shareholder as of the record date, June 20, 2025. The trade would settle on June 19, 2025. For those holding 1,000 shares, the total payout comes to 2.1 lakh. Notably, Bajaj Auto announced a dividend of 210 per share for the financial year 2025. Notably, this is the cut-off for eligible shareholders for corporate actions like dividends."
# }
# Fetching article from: https://www.autocarpro.in/news/bajaj-auto-reports-8-growth-in-may-2025-sales-despite-domestic-market-challenges-126744...
# {
#     "news_url": "https://www.autocarpro.in/news/bajaj-auto-reports-8-growth-in-may-2025-sales-despite-domestic-market-challenges-126744",
#     "news_headline": "Bajaj Auto recorded 8% growth in May 2025 sales with 3,84,621 units despite domestic market challenges, offset by strong export performance.",
#     "news_event": "Bajaj Auto achieved total sales of 3.85 lakh units with strong export performance offsetting domestic weakness across segments. Bajaj Auto recorded total sales of 3,84,621 units in May 2025, representing an 8% increase compared to 3,55,323 units sold in the same period last year. However, domestic commercial vehicle sales declined 7% to 7,50,431 units, representing only a 1% increase. Bajaj Auto is recognized as one of the largest motorcycle companies globally and holds the leadership position in the three-wheeler"
# }
# Fetching article from: https://www.bajajauto.com/corporate/media-centre...
# {
#     "news_url": "https://www.bajajauto.com/corporate/media-centre",
#     "news_headline": "Bajaj Auto launched upgraded New Pulsar RS200 2025 model with enhanced features and performance improvements for motorcycle enthusiasts.",
#     "news_event": "Togo Uganda Bajaj Auto Ltd Launches Bajaj GoGo: an All-New Brand of Electric Autos with the Largest Range in the Segment with the Biggest Range in the Segment with the Biggest Range in the Segment with over 1,000 sales in Delhi Feb 19 '25 Triumph Motorcycles Achieves over 1,000 Scrambler 400 X sales in Delhi. Extracted Event: \"Bajaj Auto Ltd Launches Bajaj GoGo: an All-New Brand of Electric Autos,\" said Bajaj Motors, an All-New Motors, an All-New Brand of Electric Motors, the Biggest Range in the Seg"
# }
# Fetching article from: https://www.bajajauto.com/corporate/media-centre...
# {
#     "news_url": "https://www.bajajauto.com/corporate/media-centre",
#     "news_headline": "Bajaj launched best Chetak yet - flagship 35 Series with 3 variants, representing significant advancement in electric scooter technology.",
#     "news_event": "Togo Uganda Bajaj Auto Ltd Launches Bajaj GoGo: an All-New Brand of Electric Autos with the Largest Range in the Segment with the Biggest Range in the Segment with the Biggest Range in the Segment with over 1,000 sales in Delhi Feb 19 '25 Triumph Motorcycles Achieves over 1,000 Scrambler 400 X sales in Delhi. Extracted Event: \"Bajaj Auto Ltd Launches Bajaj GoGo: an All-New Brand of Electric Autos,\" said Bajaj Motors, an All-New Motors, an All-New Brand of Electric Motors, the Biggest Range in the Seg"
# }
# Fetching article from: https://www.bajajauto.com/corporate/media-centre...
# {
#     "news_url": "https://www.bajajauto.com/corporate/media-centre",
#     "news_headline": "Indian Armed Forces and Bajaj Auto embarked on 'Dare2' Rally with Pulsar NS400Z, showcasing military-motorcycle partnership and adventure spirit.",
#     "news_event": "Jammu & Kashmir's Bajaj Auto Ltd launches Bajaj GoGo, an All-New Brand of Electric Autos, in India's capital, New Delhi. The company is reportedly the world's biggest E-Auto with the Longest Range in the Segment. The Extracted Event: \"Bajaj Auto Ltd Launches Bajaj GoGo: an All-New Brand of Electric Autos,\" the report stated. The report further stated that the Bajaj GoGo is the Biggest Range in India."
# }
# Fetching article from: https://economictimes.com/industry/auto/auto-news/bajaj-auto-july-sales-up-3pc...
# {
#     "news_url": "https://economictimes.com/industry/auto/auto-news/bajaj-auto-july-sales-up-3pc",
#     "news_headline": "Bajaj Auto reported 3% increase in July sales to 366,000 units with domestic sales dip of 13% offset by 28% export surge.",
#     "error": "Failed to fetch the URL: 404 Client Error: Not Found for url: https://economictimes.indiatimes.com/industry/auto/auto-news/bajaj-auto-july-sales-up-3pc"
# }
# Fetching article from: https://economictimes.indiatimes.com/bajaj-auto-ltd/stocksupdate/companyid-21430.cms...
# {
#     "news_url": "https://economictimes.indiatimes.com/bajaj-auto-ltd/stocksupdate/companyid-21430.cms",
#     "news_headline": "Issue and allotment of Commercial Paper by Bajaj Auto Credit Limited, wholly owned subsidiary, for working capital and financial management.",
#     "news_event": "Bajaj Auto, M&M, Tata Motors, and Eicher Motors lifted the Nifty Auto index by 2.8% on Monday. Bajaj Auto's sales of 4,17,616 units in August 2025, up from 3,97,804 units a year earlier, and Tata Motors' sales of 18,94,853 units versus 18,54,029 last year. Oil prices edged higher despite demand concerns related to U.S. tariffs.nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn"
# }
# Fetching article from: https://economictimes.indiatimes.com/bajaj-auto-ltd/stocksupdate/companyid-21430.cms...
# {
#     "news_url": "https://economictimes.indiatimes.com/bajaj-auto-ltd/stocksupdate/companyid-21430.cms",
#     "news_headline": "Bajaj Auto announced credit rating intimation as part of financial transparency and investor communication regarding creditworthiness assessment.",
#     "news_event": "Bajaj Auto, M&M, Tata Motors, and Eicher Motors lifted the Nifty Auto index by 2.8% on Monday. Bajaj Auto's sales of 4,17,616 units in August 2025, up from 3,97,804 units a year earlier, and Tata Motors' sales of 18,94,853 units versus 18,54,029 last year. Oil prices edged higher despite demand concerns related to U.S. tariffs.nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn"
# }
# Fetching article from: https://economictimes.indiatimes.com/bajaj-auto-ltd/stocksupdate/companyid-21430.cms...
# {
#     "news_url": "https://economictimes.indiatimes.com/bajaj-auto-ltd/stocksupdate/companyid-21430.cms",
#     "news_headline": "Submission of voting results pursuant to SEBI regulations along with scrutinizer's report for postal ballot corporate governance compliance.",
#     "news_event": "Bajaj Auto, M&M, Tata Motors, and Eicher Motors lifted the Nifty Auto index by 2.8% on Monday. Bajaj Auto's sales of 4,17,616 units in August 2025, up from 3,97,804 units a year earlier, and Tata Motors' sales of 18,94,853 units versus 18,54,029 last year. Oil prices edged higher despite demand concerns related to U.S. tariffs.nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn"
# }
# Fetching article from: https://economictimes.indiatimes.com/bajaj-auto-ltd/stocksupdate/companyid-21430.cms...
# {
#     "news_url": "https://economictimes.indiatimes.com/bajaj-auto-ltd/stocksupdate/companyid-21430.cms",
#     "news_headline": "Bajaj Auto showing signs of reversal after falling over 30% from highs, with experts suggesting medium-term buy opportunity near 100-DMA support.",
#     "news_event": "Bajaj Auto, M&M, Tata Motors, and Eicher Motors lifted the Nifty Auto index by 2.8% on Monday. Bajaj Auto's sales of 4,17,616 units in August 2025, up from 3,97,804 units a year earlier, and Tata Motors' sales of 18,94,853 units versus 18,54,029 last year. Oil prices edged higher despite demand concerns related to U.S. tariffs.nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn"
# }
# Fetching article from: https://economictimes.indiatimes.com/bajaj-auto-ltd/stocksupdate/companyid-21430.cms...
# {
#     "news_url": "https://economictimes.indiatimes.com/bajaj-auto-ltd/stocksupdate/companyid-21430.cms",
#     "news_headline": "Bajaj Auto scheduled analyst conference call for September 2, 2025, for investor communication and business performance discussions.",
#     "news_event": "Bajaj Auto, M&M, Tata Motors, and Eicher Motors lifted the Nifty Auto index by 2.8% on Monday. Bajaj Auto's sales of 4,17,616 units in August 2025, up from 3,97,804 units a year earlier, and Tata Motors' sales of 18,94,853 units versus 18,54,029 last year. Oil prices edged higher despite demand concerns related to U.S. tariffs.nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn"
# }
# All extracted events saved to extracted_events.json
